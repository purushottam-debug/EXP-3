# %%
from sklearn.ensemble import RandomForestClassifier
clf= RandomForestClassifier(random_state=0)
X=[[1,2,3],[11,12,13]]
y=[0,1]
clf.fit(X,y)
RandomForestClassifier(random_state=0)
# Out:
# RandomForestClassifier(random_state=0)

# %%
clf.predict(X)
Out[15]:
array([0, 1])

# %%
clf.predict([[4,5,6],[14,15,16]])
# Out:
# array([0, 1])

# %%
from sklearn.preprocessing import StandardScaler
X=[[0,15],[1,-10]]
clf.predict([[4,5,6],[14,15,16]])
StandardScaler().fit(X).transform(X)
# Out:
# array([[-1.,  1.],
#        [ 1., -1.]])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# create a pipeline object
pipe = make_pipeline(StandardScaler(),LogisticRegression(random_state=0))
 # load the iris dataset and split it into train and test sets
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
pipe.fit(X_train, y_train)
Pipeline(steps=[('standardscaler', StandardScaler()),
                ('logisticregression', LogisticRegression(random_state=0))])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ceae5d05deb6> in <module>
# ----> 1 pipe.fit(X_train, y_train)
#       2 Pipeline(steps=[('standardscaler', StandardScaler()),
#       3                 ('logisticregression', LogisticRegression(random_state=0))])
#
# NameError: name 'pipe' is not defined

# %%
accuracy_score(pipe.predict(X_test), y_test)
0
Out[30]:
0

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate

X, y = make_regression(n_samples=1000, random_state=0)
lr = LinearRegression()

result = cross_validate(lr, X, y)
result['test_score']
# Out:
# array([1., 1., 1., 1., 1.])
